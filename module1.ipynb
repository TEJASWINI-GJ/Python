# %% [markdown]
# Some of the Print Statements

# %%
print ("Hello world!")
# Out:
# Hello world!

# %%
print ("Welcome to VAC, programming in Python")
# Out:
# Welcome to VAC, programming in Python

# %%
if 5 > 2:
  print ("Five is greater than 2")
# Out:
# Five is greater than 2

# %%
x=5
y="Gubbi"
print (x)
print(y)
# Out:
# 5
# Gubbi
